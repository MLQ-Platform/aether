# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

os.chdir("..")

# %%
from aether.clause.nodes.nodes import SMA
from aether.clause.nodes.nodes import ADD
from aether.clause.nodes.nodes import SHIFT
from aether.clause.nodes.nodes import DIFF
from aether.clause.nodes.nodes import PctChange
from aether.clause.nodes.nodes import ShiftSign
from aether.clause.nodes.nodes import ABS
from aether.clause.nodes.nodes import DIV
from aether.clause.nodes.nodes import SUB
from aether.clause.nodes.nodes import MAX
from aether.clause.nodes.nodes import MIN
from aether.clause.nodes.nodes import Comparison
from aether.clause.nodes.nodes import NewHigh
from aether.clause.nodes.nodes import NewLow
from aether.clause.nodes.nodes import STD
from aether.clause.nodes.nodes import SKEW
from aether.clause.nodes.nodes import KURT
from aether.clause.nodes.nodes import DATA
from aether.clause.nodes.nodes import LargerThan
from aether.clause.nodes.nodes import SmallerThan
from aether.clause.nodes.nodes import ZBetween
from aether.clause.nodes.nodes import EqualApprox
from aether.clause.nodes.nodes import ZEXP
from aether.clause.nodes.nodes import ZSigmoid
from aether.clause.nodes.nodes import CrossUp
from aether.clause.nodes.nodes import CrossDown

from aether.clause.tree import ClauseTree
from aether.clause.tree.generator import ClauseGenerator
from aether.provider import InMemoryDataProvider

# %%
data_provider = InMemoryDataProvider()
# Out:
# Loading dataframes ...: 100%|██████████| 80/80 [00:00<00:00, 199.14it/s]

# %%
data_node_a = DATA(label = "HIGH", ticker= "BTCUSDT")
data_node_b = DATA(label = "OPEN", ticker= "ETHUSDT")

# %%
seq_a = data_node_a.activate()
seq_b = data_node_b.activate()

# %%
MAX(period=10).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00         NaN
# 2021-01-01 02:00:00         NaN
# 2021-01-01 03:00:00         NaN
# 2021-01-01 04:00:00         NaN
# 2021-01-01 05:00:00         NaN
#                          ...
# 2025-06-29 20:00:00    108499.0
# 2025-06-29 21:00:00    108499.0
# 2025-06-29 22:00:00    108499.0
# 2025-06-29 23:00:00    108225.8
# 2025-06-30 00:00:00    108400.0
# Name: HIGH, Length: 39384, dtype: float64

# %%
MIN(period=10).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00         NaN
# 2021-01-01 02:00:00         NaN
# 2021-01-01 03:00:00         NaN
# 2021-01-01 04:00:00         NaN
# 2021-01-01 05:00:00         NaN
#                          ...
# 2025-06-29 20:00:00    107541.4
# 2025-06-29 21:00:00    107431.8
# 2025-06-29 22:00:00    107431.8
# 2025-06-29 23:00:00    107431.8
# 2025-06-30 00:00:00    107431.8
# Name: HIGH, Length: 39384, dtype: float64

# %%
SMA(period=5).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00          NaN
# 2021-01-01 02:00:00          NaN
# 2021-01-01 03:00:00          NaN
# 2021-01-01 04:00:00          NaN
# 2021-01-01 05:00:00     29380.63
#                          ...
# 2025-06-29 20:00:00    107697.44
# 2025-06-29 21:00:00    107588.30
# 2025-06-29 22:00:00    107579.14
# 2025-06-29 23:00:00    107716.02
# 2025-06-30 00:00:00    107863.60
# Name: HIGH, Length: 39384, dtype: float64

# %%
ADD().activate(seq_a, seq_b)
# Out:
# close_time
# 2021-01-01 01:00:00     29792.18
# 2021-01-01 02:00:00     30281.03
# 2021-01-01 03:00:00     30249.37
# 2021-01-01 04:00:00     30124.56
# 2021-01-01 05:00:00     30168.22
#                          ...
# 2025-06-29 20:00:00    110007.25
# 2025-06-29 21:00:00    109868.60
# 2025-06-29 22:00:00    110120.99
# 2025-06-29 23:00:00    110655.95
# 2025-06-30 00:00:00    110901.00
# Length: 39384, dtype: float64

# %%
SHIFT(period=2).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00          NaN
# 2021-01-01 02:00:00          NaN
# 2021-01-01 03:00:00     29055.00
# 2021-01-01 04:00:00     29546.42
# 2021-01-01 05:00:00     29500.00
#                          ...
# 2025-06-29 20:00:00    107541.40
# 2025-06-29 21:00:00    107662.10
# 2025-06-29 22:00:00    107570.50
# 2025-06-29 23:00:00    107431.80
# 2025-06-30 00:00:00    107689.90
# Name: HIGH, Length: 39384, dtype: float64

# %%
DIFF(period=2).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00       NaN
# 2021-01-01 02:00:00       NaN
# 2021-01-01 03:00:00    445.00
# 2021-01-01 04:00:00   -167.01
# 2021-01-01 05:00:00    -77.68
#                         ...
# 2025-06-29 20:00:00     29.10
# 2025-06-29 21:00:00   -230.30
# 2025-06-29 22:00:00    119.40
# 2025-06-29 23:00:00    794.00
# 2025-06-30 00:00:00    710.10
# Name: HIGH, Length: 39384, dtype: float64

# %%
PctChange(period=1).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00         NaN
# 2021-01-01 02:00:00    0.016913
# 2021-01-01 03:00:00   -0.001571
# 2021-01-01 04:00:00   -0.004088
# 2021-01-01 05:00:00    0.001461
#                          ...
# 2025-06-29 20:00:00   -0.000851
# 2025-06-29 21:00:00   -0.001289
# 2025-06-29 22:00:00    0.002402
# 2025-06-29 23:00:00    0.004976
# 2025-06-30 00:00:00    0.001610
# Name: HIGH, Length: 39384, dtype: float64

# %%
ShiftSign().activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00    -29055.00
# 2021-01-01 02:00:00    -29546.42
# 2021-01-01 03:00:00    -29500.00
# 2021-01-01 04:00:00    -29379.41
# 2021-01-01 05:00:00    -29422.32
#                          ...
# 2025-06-29 20:00:00   -107570.50
# 2025-06-29 21:00:00   -107431.80
# 2025-06-29 22:00:00   -107689.90
# 2025-06-29 23:00:00   -108225.80
# 2025-06-30 00:00:00   -108400.00
# Name: HIGH, Length: 39384, dtype: float64

# %%
ABS().activate(-1 * seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00     29055.00
# 2021-01-01 02:00:00     29546.42
# 2021-01-01 03:00:00     29500.00
# 2021-01-01 04:00:00     29379.41
# 2021-01-01 05:00:00     29422.32
#                          ...
# 2025-06-29 20:00:00    107570.50
# 2025-06-29 21:00:00    107431.80
# 2025-06-29 22:00:00    107689.90
# 2025-06-29 23:00:00    108225.80
# 2025-06-30 00:00:00    108400.00
# Name: HIGH, Length: 39384, dtype: float64

# %%
DIV().activate(seq_a, seq_b)
# Out:
# close_time
# 2021-01-01 01:00:00    39.413712
# 2021-01-01 02:00:00    40.220552
# 2021-01-01 03:00:00    39.366401
# 2021-01-01 04:00:00    39.427511
# 2021-01-01 05:00:00    39.445395
#                          ...
# 2025-06-29 20:00:00    44.145070
# 2025-06-29 21:00:00    44.087246
# 2025-06-29 22:00:00    44.296961
# 2025-06-29 23:00:00    44.534617
# 2025-06-30 00:00:00    43.342663
# Length: 39384, dtype: float64

# %%
SUB().activate(seq_a, seq_b)
# Out:
# close_time
# 2021-01-01 01:00:00     28317.82
# 2021-01-01 02:00:00     28811.81
# 2021-01-01 03:00:00     28750.63
# 2021-01-01 04:00:00     28634.26
# 2021-01-01 05:00:00     28676.42
#                          ...
# 2025-06-29 20:00:00    105133.75
# 2025-06-29 21:00:00    104995.00
# 2025-06-29 22:00:00    105258.81
# 2025-06-29 23:00:00    105795.65
# 2025-06-30 00:00:00    105899.00
# Length: 39384, dtype: float64

# %%
Comparison().activate(seq_a, seq_b)
# Out:
# close_time
# 2021-01-01 01:00:00    True
# 2021-01-01 02:00:00    True
# 2021-01-01 03:00:00    True
# 2021-01-01 04:00:00    True
# 2021-01-01 05:00:00    True
#                        ...
# 2025-06-29 20:00:00    True
# 2025-06-29 21:00:00    True
# 2025-06-29 22:00:00    True
# 2025-06-29 23:00:00    True
# 2025-06-30 00:00:00    True
# Length: 39384, dtype: bool

# %%
NewHigh(period=10).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00    False
# 2021-01-01 02:00:00    False
# 2021-01-01 03:00:00    False
# 2021-01-01 04:00:00    False
# 2021-01-01 05:00:00    False
#                        ...
# 2025-06-29 20:00:00    False
# 2025-06-29 21:00:00    False
# 2025-06-29 22:00:00    False
# 2025-06-29 23:00:00     True
# 2025-06-30 00:00:00     True
# Name: HIGH, Length: 39384, dtype: bool

# %%
NewLow(period=10).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00    False
# 2021-01-01 02:00:00    False
# 2021-01-01 03:00:00    False
# 2021-01-01 04:00:00    False
# 2021-01-01 05:00:00    False
#                        ...
# 2025-06-29 20:00:00    False
# 2025-06-29 21:00:00     True
# 2025-06-29 22:00:00    False
# 2025-06-29 23:00:00    False
# 2025-06-30 00:00:00    False
# Name: HIGH, Length: 39384, dtype: bool

# %%
ZSCORE(period=30).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00         NaN
# 2021-01-01 02:00:00         NaN
# 2021-01-01 03:00:00         NaN
# 2021-01-01 04:00:00         NaN
# 2021-01-01 05:00:00         NaN
#                          ...
# 2025-06-29 20:00:00   -0.072486
# 2025-06-29 21:00:00   -0.456484
# 2025-06-29 22:00:00    0.208784
# 2025-06-29 23:00:00    1.492122
# 2025-06-30 00:00:00    1.755233
# Name: HIGH, Length: 39384, dtype: float64

# %%
CORR(period=30).activate(seq_a, seq_b)
# Out:
# close_time
# 2021-01-01 01:00:00         NaN
# 2021-01-01 02:00:00         NaN
# 2021-01-01 03:00:00         NaN
# 2021-01-01 04:00:00         NaN
# 2021-01-01 05:00:00         NaN
#                          ...
# 2025-06-29 20:00:00    0.860451
# 2025-06-29 21:00:00    0.860769
# 2025-06-29 22:00:00    0.871983
# 2025-06-29 23:00:00    0.772438
# 2025-06-30 00:00:00    0.689696
# Length: 39384, dtype: float64

# %%
STD(period=30).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00           NaN
# 2021-01-01 02:00:00           NaN
# 2021-01-01 03:00:00           NaN
# 2021-01-01 04:00:00           NaN
# 2021-01-01 05:00:00           NaN
#                           ...
# 2025-06-29 20:00:00    385.499447
# 2025-06-29 21:00:00    380.327191
# 2025-06-29 22:00:00    380.409884
# 2025-06-29 23:00:00    395.541761
# 2025-06-30 00:00:00    418.290231
# Name: HIGH, Length: 39384, dtype: float64

# %%
SKEW(period=30).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00         NaN
# 2021-01-01 02:00:00         NaN
# 2021-01-01 03:00:00         NaN
# 2021-01-01 04:00:00         NaN
# 2021-01-01 05:00:00         NaN
#                          ...
# 2025-06-29 20:00:00    1.130452
# 2025-06-29 21:00:00    1.150808
# 2025-06-29 22:00:00    1.107883
# 2025-06-29 23:00:00    0.921741
# 2025-06-30 00:00:00    0.773805
# Name: HIGH, Length: 39384, dtype: float64

# %%
KURT(period=30).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00         NaN
# 2021-01-01 02:00:00         NaN
# 2021-01-01 03:00:00         NaN
# 2021-01-01 04:00:00         NaN
# 2021-01-01 05:00:00         NaN
#                          ...
# 2025-06-29 20:00:00    0.161798
# 2025-06-29 21:00:00    0.217876
# 2025-06-29 22:00:00    0.145826
# 2025-06-29 23:00:00   -0.408289
# 2025-06-30 00:00:00   -0.817910
# Name: HIGH, Length: 39384, dtype: float64

# %%
LargerThan(n=90000).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00    False
# 2021-01-01 02:00:00    False
# 2021-01-01 03:00:00    False
# 2021-01-01 04:00:00    False
# 2021-01-01 05:00:00    False
#                        ...
# 2025-06-29 20:00:00     True
# 2025-06-29 21:00:00     True
# 2025-06-29 22:00:00     True
# 2025-06-29 23:00:00     True
# 2025-06-30 00:00:00     True
# Name: HIGH, Length: 39384, dtype: bool

# %%
SmallerThan(n=90000).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00     True
# 2021-01-01 02:00:00     True
# 2021-01-01 03:00:00     True
# 2021-01-01 04:00:00     True
# 2021-01-01 05:00:00     True
#                        ...
# 2025-06-29 20:00:00    False
# 2025-06-29 21:00:00    False
# 2025-06-29 22:00:00    False
# 2025-06-29 23:00:00    False
# 2025-06-30 00:00:00    False
# Name: HIGH, Length: 39384, dtype: bool

# %%
Between(lo=50000, hi=120000).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00    False
# 2021-01-01 02:00:00    False
# 2021-01-01 03:00:00    False
# 2021-01-01 04:00:00    False
# 2021-01-01 05:00:00    False
#                        ...
# 2025-06-29 20:00:00     True
# 2025-06-29 21:00:00     True
# 2025-06-29 22:00:00     True
# 2025-06-29 23:00:00     True
# 2025-06-30 00:00:00     True
# Name: HIGH, Length: 39384, dtype: bool

# %%
EqualApprox(n=108400.00).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00    False
# 2021-01-01 02:00:00    False
# 2021-01-01 03:00:00    False
# 2021-01-01 04:00:00    False
# 2021-01-01 05:00:00    False
#                        ...
# 2025-06-29 20:00:00    False
# 2025-06-29 21:00:00    False
# 2025-06-29 22:00:00    False
# 2025-06-29 23:00:00    False
# 2025-06-30 00:00:00     True
# Name: HIGH, Length: 39384, dtype: bool

# %%
CLIP(lo=0, hi=1).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00    1.0
# 2021-01-01 02:00:00    1.0
# 2021-01-01 03:00:00    1.0
# 2021-01-01 04:00:00    1.0
# 2021-01-01 05:00:00    1.0
#                       ...
# 2025-06-29 20:00:00    1.0
# 2025-06-29 21:00:00    1.0
# 2025-06-29 22:00:00    1.0
# 2025-06-29 23:00:00    1.0
# 2025-06-30 00:00:00    1.0
# Name: HIGH, Length: 39384, dtype: float64

# %%
ZEXP(period=50).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00          NaN
# 2021-01-01 02:00:00          NaN
# 2021-01-01 03:00:00          NaN
# 2021-01-01 04:00:00          NaN
# 2021-01-01 05:00:00          NaN
#                          ...
# 2025-06-29 20:00:00     1.389324
# 2025-06-29 21:00:00     0.917363
# 2025-06-29 22:00:00     1.853897
# 2025-06-29 23:00:00     7.658526
# 2025-06-30 00:00:00    10.268641
# Name: HIGH, Length: 39384, dtype: float64

# %%
ZSigmoid(period=50).activate(seq_a)
# Out:
# close_time
# 2021-01-01 01:00:00         NaN
# 2021-01-01 02:00:00         NaN
# 2021-01-01 03:00:00         NaN
# 2021-01-01 04:00:00         NaN
# 2021-01-01 05:00:00         NaN
#                          ...
# 2025-06-29 20:00:00    0.581472
# 2025-06-29 21:00:00    0.478450
# 2025-06-29 22:00:00    0.649602
# 2025-06-29 23:00:00    0.884507
# 2025-06-30 00:00:00    0.911258
# Name: HIGH, Length: 39384, dtype: float64

# %%
CrossUP().activate(seq_a, seq_b)
# Out:
# close_time
# 2021-01-01 01:00:00    False
# 2021-01-01 02:00:00    False
# 2021-01-01 03:00:00    False
# 2021-01-01 04:00:00    False
# 2021-01-01 05:00:00    False
#                        ...
# 2025-06-29 20:00:00    False
# 2025-06-29 21:00:00    False
# 2025-06-29 22:00:00    False
# 2025-06-29 23:00:00    False
# 2025-06-30 00:00:00    False
# Length: 39384, dtype: bool

# %%
CrossDown().activate(seq_a, seq_b)
# Out:
# close_time
# 2021-01-01 01:00:00    False
# 2021-01-01 02:00:00    False
# 2021-01-01 03:00:00    False
# 2021-01-01 04:00:00    False
# 2021-01-01 05:00:00    False
#                        ...
# 2025-06-29 20:00:00    False
# 2025-06-29 21:00:00    False
# 2025-06-29 22:00:00    False
# 2025-06-29 23:00:00    False
# 2025-06-30 00:00:00    False
# Length: 39384, dtype: bool

# %%
from aether.clause.nodes.nodes import SlopeSignChange

SlopeSignChange(p=10).activate(seq_a).value_counts()
# Out:
# HIGH
# False    35027
# True      4357
# Name: count, dtype: int64

# %%
from aether.clause.nodes.nodes import UpStreak

UpStreak(p=3).activate(seq_a).value_counts()
# Out:
# HIGH
# False    35220
# True      4164
# Name: count, dtype: int64

# %%
from aether.clause.nodes.nodes import DownStreak 

DownStreak(p=3).activate(seq_a).value_counts()
# Out:
# HIGH
# False    32968
# True      6416
# Name: count, dtype: int64

# %%
from aether.clause.nodes.nodes import MeanRevertKick

MeanRevertKick(p=10, z_th=2, dmax=3, eps=0.3).activate(seq_a).value_counts()
# Out:
# HIGH
# False    36228
# True      3156
# Name: count, dtype: int64

# %%
from aether.clause.nodes.nodes import PullbackWithinBand

PullbackWithinBand(p=10, k=2.0).activate(seq_a).value_counts()
# Out:
# HIGH
# False    36954
# True      2430
# Name: count, dtype: int64

# %%
from aether.clause.nodes.nodes import DrawdownExceed

DrawdownExceed(pct=0.1, lookback=30).activate(seq_a).value_counts()
# Out:
# HIGH
# False    38922
# True       462
# Name: count, dtype: int64

# %%
from aether.clause.nodes.nodes import JumpDetect

JumpDetect(p=10, q_tail=0.1).activate(seq_a).value_counts()
# Out:
# HIGH
# False    35345
# True      4039
# Name: count, dtype: int64
